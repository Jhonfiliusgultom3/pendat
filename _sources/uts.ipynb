# %% [markdown]
# # UJIAN TENGAH SEMESTER

# %% [markdown]
# # Metode Naive Bayes Classification
#
# # Importing the libraries

# %% [markdown]
# Naive bayes merupakan metode pengklasifikasian berdasarkan probabilitas sederhana dan dirancang agar dapat dipergunakan dengan asumsi antar variabel penjelas saling bebas (independen).

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('https://raw.githubusercontent.com/datasets/breast-cancer/master/data/breast-cancer.csv')

# %%
dataset.head()
# Out:
#      age mefalsepause tumor-size inv-falsedes falsede-caps  deg-malig breast  \
# 0  40-49   premefalse      15-19          0-2         True          3  right
# 1  50-59         ge40      15-19          0-2        False          1  right
# 2  50-59         ge40      35-39          0-2        False          2   left
# 3  40-49   premefalse      35-39          0-2         True          3  right
# 4  40-49   premefalse      30-34          3-5         True          2   left
#
#   breast-quad  irradiat                    class
# 0     left_up     False        recurrence-events
# 1     central     False  false-recurrence-events
# 2    left_low     False        recurrence-events
# 3    left_low      True  false-recurrence-events
# 4    right_up     False        recurrence-events

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 272 entries, 0 to 271
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age           272 non-null    object
#  1   mefalsepause  272 non-null    object
#  2   tumor-size    272 non-null    object
#  3   inv-falsedes  272 non-null    object
#  4   falsede-caps  264 non-null    object
#  5   deg-malig     272 non-null    int64
#  6   breast        272 non-null    object
#  7   breast-quad   271 non-null    object
#  8   irradiat      272 non-null    bool
#  9   class         272 non-null    object
# dtypes: bool(1), int64(1), object(8)
# memory usage: 19.5+ KB

# %%
dataset = dataset.drop(["class"], axis = 1)

# %%
dataset.head(3)
# Out:
#   mefalsepause tumor-size inv-falsedes falsede-caps  deg-malig breast  \
# 0   premefalse      15-19          0-2         True          3  right
# 1         ge40      15-19          0-2        False          1  right
# 2         ge40      35-39          0-2        False          2   left
#
#   breast-quad  irradiat
# 0     left_up     False
# 1     central     False
# 2    left_low     False

# %%
A = dataset[dataset.mefalsepause == "ge40"]

# %%
A.head(5)
# Out:
#    mefalsepause tumor-size inv-falsedes falsede-caps  deg-malig breast  \
# 1          ge40      15-19          0-2        False          1  right
# 2          ge40      35-39          0-2        False          2   left
# 6          ge40      40-44          0-2        False          3   left
# 9          ge40      40-44        15-17         True          2  right
# 11         ge40      15-19          0-2        False          2  right
#
#    breast-quad  irradiat
# 1      central     False
# 2     left_low     False
# 6      left_up     False
# 9      left_up      True
# 11     left_up     False

# %%
B = dataset[dataset.mefalsepause == "premefalse"]

# %%
B.head(5)
# Out:
#   mefalsepause tumor-size inv-falsedes falsede-caps  deg-malig breast  \
# 0   premefalse      15-19          0-2         True          3  right
# 3   premefalse      35-39          0-2         True          3  right
# 4   premefalse      30-34          3-5         True          2   left
# 5   premefalse      25-29          3-5        False          2  right
# 7   premefalse      10-14          0-2        False          2   left
#
#   breast-quad  irradiat
# 0     left_up     False
# 3    left_low      True
# 4    right_up     False
# 5     left_up      True
# 7     left_up     False

# %% [markdown]
# # Metode Knn

# %%
#split dataset into train and test data
from sklearn.model_selection import train_test_split

# %%
# Create KNN classifier
from sklearn.neighbors import KNeighborsClassifier

# %%
import pandas as pd

# %%
dataset_url = "https://raw.githubusercontent.com/datasets/breast-cancer/master/data/breast-cancer.csv"

# %%
df = pd.read_csv(dataset_url)
df.head()
# Out:
#      age mefalsepause tumor-size inv-falsedes falsede-caps  deg-malig breast  \
# 0  40-49   premefalse      15-19          0-2         True          3  right
# 1  50-59         ge40      15-19          0-2        False          1  right
# 2  50-59         ge40      35-39          0-2        False          2   left
# 3  40-49   premefalse      35-39          0-2         True          3  right
# 4  40-49   premefalse      30-34          3-5         True          2   left
#
#   breast-quad  irradiat                    class
# 0     left_up     False        recurrence-events
# 1     central     False  false-recurrence-events
# 2    left_low     False        recurrence-events
# 3    left_low      True  false-recurrence-events
# 4    right_up     False        recurrence-events

# %%
#check number of rows and columns in dataset
df.shape
# Out:
# (272, 10)

# %% [markdown]
# #Hitung Data

# %%
dataset.mefalsepause = [1 if i == "A" else 0 for i in dataset.mefalsepause]

# %%
x = dataset.drop(["mefalsepause"], axis = 1)
y = dataset.mefalsepause.values
