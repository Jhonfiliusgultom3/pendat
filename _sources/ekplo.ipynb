# %% [markdown]
# # EXPLORASI DATA

# %% [markdown]
# Eksplorasi data adalah proses untuk menggali dan menganalisis data secara menyeluruh dengan tujuan memahami karakteristik data, menemukan pola atau tren yang menarik, serta mengidentifikasi hubungan atau insight penting yang terkandung dalam data. Tujuan utama dari eksplorasi data adalah untuk mendapatkan pemahaman yang lebih baik tentang data yang ada sebelum melakukan analisis lebih lanjut atau pengambilan keputusan.
#
# Menarik data iris dari postgesql kemudian dibaca dengan phyton dijadikan dataframe jalankan dijupyter notebok di local

# %% [raw]
# Nama : Jhon Filius Gultom
# Nim  : 210411100019

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.5.3'

# %%
pd.read_csv("dataku.csv")
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0    sepal.length  sepal.width  petal.length  petal.width    variety
# 1             5.1          3.5           1.4           .2     Setosa
# 2             4.9            3           1.4           .2     Setosa
# 3             4.7          3.2           1.3           .2     Setosa
# 4             4.6          3.1           1.5           .2     Setosa
# ..            ...          ...           ...          ...        ...
# 146           6.7            3           5.2          2.3  Virginica
# 147           6.3          2.5             5          1.9  Virginica
# 148           6.5            3           5.2            2  Virginica
# 149           6.2          3.4           5.4          2.3  Virginica
# 150           5.9            3           5.1          1.8  Virginica
#
# [151 rows x 5 columns]

# %%
DATA_IRIS = pd.read_csv("dataku.csv")
# Print Dataframe
DATA_IRIS
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0    sepal.length  sepal.width  petal.length  petal.width    variety
# 1             5.1          3.5           1.4           .2     Setosa
# 2             4.9            3           1.4           .2     Setosa
# 3             4.7          3.2           1.3           .2     Setosa
# 4             4.6          3.1           1.5           .2     Setosa
# ..            ...          ...           ...          ...        ...
# 146           6.7            3           5.2          2.3  Virginica
# 147           6.3          2.5             5          1.9  Virginica
# 148           6.5            3           5.2            2  Virginica
# 149           6.2          3.4           5.4          2.3  Virginica
# 150           5.9            3           5.1          1.8  Virginica
#
# [151 rows x 5 columns]

# %% [raw]
# Cara yang lain :

# %%
import psycopg2

# %%
import pandas as pd

# %%
conn = psycopg2.connect(
    database="postgres",
    host="localhost",
    user="postgres",
    password="176283565"
)


query ="SELECT * FROM data_iris"

df= pd.read_sql_query(query, conn)

conn.close()

print(df)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0    sepal.length  sepal.width  petal.length  petal.width    variety
# 1             5.1          3.5           1.4           .2     Setosa
# 2             4.9            3           1.4           .2     Setosa
# 3             4.7          3.2           1.3           .2     Setosa
# 4             4.6          3.1           1.5           .2     Setosa
# ..            ...          ...           ...          ...        ...
# 146           6.7            3           5.2          2.3  Virginica
# 147           6.3          2.5             5          1.9  Virginica
# 148           6.5            3           5.2            2  Virginica
# 149           6.2          3.4           5.4          2.3  Virginica
# 150           5.9            3           5.1          1.8  Virginica
#
# [151 rows x 5 columns]
# ...
